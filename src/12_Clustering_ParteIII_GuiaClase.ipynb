# %% [markdown]
# # Practica 3: Clustering - Parte III
# En esta parte de la práctica usaremos lo que hemos aprendido de agrupamiento para realizar un analisis de segmentación de mercado. Para esta parte se requiere el archivo customer.csv.
#
# Los datos fueron previamente limpiados, eliminando datos nulos y algunas anomalias, datos categoricos se codificaron a valores enteros.

# %%
#Importamos las librerias
#Visualización de datos

# %%
#Cargamos el archivo

# %%
#Revisamos los tipos de datos

# %%
#Revisamos los primeros 5 elementos

# %% [markdown]
# Para este proceso vamos a realizar los siguientes pasos:
#
#
# 1.   Normalización de datos
# 2.   Revisión de los datos correlacionados: nos da una idea si podemos eliminar alguna de las dimensiones
# 3.   Vamos aplicar inicialmente Kmeans para hacer el analisis de los segmentos de mercado

# %%
#Importamos

#Normalizamos

# %%
#Analizamos la correlacion de los datos con un mapa de calor

# %% [markdown]
# # Kmeans

# %%
#Importar Kmeans



# arreglos para indices

# %%
#Graficamos el resultado
plt.figure(figsize=(15, 5))
plt.subplot(1,3,1)
plt.plot(range(2,16),inertias,'b',marker='o',)
plt.subplot(1,3,2)
plt.plot(range(2,16),db,'r',marker='o')
plt.subplot(1,3,3)
plt.plot(range(2,16),silhouette,'g',marker='o')

# %% [markdown]
# Determinamos el número de cluster a partir del analisis de las graficas anteriores.

# %%
#Seleccionamos numero de cluster y obtenemos el agrupamiento

# %%
#Agregamos la información de los clusters a los datos originales

# %%
#Analizamos variables de interes
#Ej: como se comporta lo que gasta un cliente vs sus ingresos

# %%
#Ej: cual es el nivel de aceptación de las promociones

# %%
#Como es el comportamiento respecto a información demografica
Personal = ['Kidhome', 'Teenhome', 'Age_on_2014', 'Children', 'Family_size', 'Is_parent', 'Education', 'Living_with']

for i in Personal:
  plt.figure(figsize = (12, 6))
  sns.jointplot(x = df[i], y = df['Spent'], hue = df['Cluster'], kind = 'kde')
  plt.show()
